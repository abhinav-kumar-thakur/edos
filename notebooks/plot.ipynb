# %%
# %cd ..
# Out:
# /scratch/abhinav/edos

# %%
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline

from src.utils import plot_metrics

# %%
log_file = "/scratch/abhinav/edos/logs/B1-bertweet-base-ssl-v1/train.log"

# %%
filter = {
    # "Kth Fold": 0,
}

y_metrics = [
    # ('eval', 'a', 'sexist', 'f1-score'),
    # ('eval', 'a', 'not sexist', 'f1-score'),
    # ('eval', 'b', '1. threats, plans to harm and incitement', 'f1-score'),
    # ('eval', 'b', '2. derogation', 'f1-score'),
    # ('eval', 'b', '3. animosity', 'f1-score'),
    # ('eval', 'b', '4. prejudiced discussions', 'f1-score'),
    ('eval', 'b', 'macro avg', 'f1-score')
]

x_metrics = [
    ('train', 'Epoch')
]

# %%
plot_metrics(log_file, y_metrics, x_metrics, filter)

# %%
filter = {
    "Kth Fold": 0,
}

y_metrics = [
    ('eval', 'a', 'sexist', 'recall'),
    ('eval', 'a', 'not sexist', 'recall')
]

x_metrics = [
    ('train', 'Epoch')
]

plot_metrics(log_file, y_metrics, x_metrics, filter)

# %%
filter = {
    "Kth Fold": 0,
}

y_metrics = [
    ('eval', 'a', 'sexist', 'precision'),
    ('eval', 'a', 'not sexist', 'precision')
]

x_metrics = [
    ('train', 'Epoch')
]

plot_metrics(log_file, y_metrics, x_metrics, filter)
